# %%
from tensorflow.keras.applications.densenet import DenseNet201 as b # DenseNet169, DenseNet121
import numpy as np
import pandas as pd
from matplotlib import ticker
#import seaborn as sn
import PIL
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
import subprocess as sp
import os

def mask_unused_gpus(leave_unmasked=1):
  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"

  try:
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    available_gpus = [i for i, x in enumerate(memory_free_values) if x > ACCEPTABLE_AVAILABLE_MEMORY]

    if len(available_gpus) < leave_unmasked: raise ValueError('Found only %d usable GPUs in the system' % len(available_gpus))
    os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, available_gpus[:leave_unmasked]))
  except Exception as e:
    print('"nvidia-smi" is probably not installed. GPUs are not masked', e)

mask_unused_gpus()

# %%
traingen = image.ImageDataGenerator(rescale=1./255)#,rotation_range=10,width_shift_range=20,height_shift_range=10,shear_range=10,horizontal_flip=True,vertical_flip=True)
validationgen = image.ImageDataGenerator(rescale=1./255)
testgen = image.ImageDataGenerator(rescale=1./255)

train = traingen.flow_from_directory("train",target_size=(500, 825), batch_size=50, shuffle=True)
val = validationgen.flow_from_directory("validation",target_size=(500, 825), batch_size=56, shuffle=False)
test=testgen.flow_from_directory("test",target_size=(500, 825), batch_size=32, shuffle=False)
# Out:
# Found 2049 images belonging to 16 classes.
# Found 684 images belonging to 16 classes.
# Found 683 images belonging to 16 classes.

# %%
call_list = [tf.keras.callbacks.ModelCheckpoint(
                 filepath='./Dense/trD_121-{epoch:02d}-{val_categorical_accuracy:.4f}-{categorical_accuracy:.4f}.h5',
                 monitor='val_categorical_accuracy',
                 save_best_only=False,),
             
             tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta=0.001,patience=4,),
             tf.keras.callbacks.EarlyStopping(monitor='categorical_accuracy',min_delta=0.0005,patience=6,),
             tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy',min_delta=0.0005,patience=8,),
             
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_delta=0.005,),
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',factor=0.5,patience=4,min_delta=0.005,)
            ]
    
    
base = b(include_top=False,
                weights="imagenet",
                input_shape=(500, 825, 3))

x = base.output
#x = layers.Dropout(0.5)(x)
#x = layers.GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
#x = layers.Dense(16, activation='selu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
predictions = layers.Dense(16, activation='softmax')(x)#, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)

model = Model(inputs=base.input, outputs=predictions)

# this is the model we will train

for layer in base.layers:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=["categorical_accuracy","top_k_categorical_accuracy"])
    
    
history = model.fit_generator(train,
                              #callbacks=call_list,
                              steps_per_epoch=np.ceil(2049/50),
                              epochs=50,
                              verbose=2,
                              validation_data= val,
                              validation_steps=np.ceil(684/56)
                              )
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histDense201pre.csv")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1104 12:17:26.043802 140032681375552 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 10s 0us/step
# Epoch 1/50
# 41/41 - 72s - loss: 5.8835 - categorical_accuracy: 0.1562 - top_k_categorical_accuracy: 0.5095 - val_loss: 3.7910 - val_categorical_accuracy: 0.2281 - val_top_k_categorical_accuracy: 0.5585
# Epoch 2/50
# 41/41 - 47s - loss: 3.0759 - categorical_accuracy: 0.3743 - top_k_categorical_accuracy: 0.7604 - val_loss: 3.0645 - val_categorical_accuracy: 0.2997 - val_top_k_categorical_accuracy: 0.6681
# Epoch 3/50
# 41/41 - 46s - loss: 2.3178 - categorical_accuracy: 0.4915 - top_k_categorical_accuracy: 0.8482 - val_loss: 3.3074 - val_categorical_accuracy: 0.2953 - val_top_k_categorical_accuracy: 0.6901
# Epoch 4/50
# 41/41 - 47s - loss: 1.8432 - categorical_accuracy: 0.5603 - top_k_categorical_accuracy: 0.8941 - val_loss: 3.1652 - val_categorical_accuracy: 0.3465 - val_top_k_categorical_accuracy: 0.6813
# Epoch 5/50
# 41/41 - 48s - loss: 1.5312 - categorical_accuracy: 0.6159 - top_k_categorical_accuracy: 0.9204 - val_loss: 3.0059 - val_categorical_accuracy: 0.3436 - val_top_k_categorical_accuracy: 0.7076
# Epoch 6/50
# 41/41 - 48s - loss: 1.3008 - categorical_accuracy: 0.6672 - top_k_categorical_accuracy: 0.9346 - val_loss: 3.0129 - val_categorical_accuracy: 0.3480 - val_top_k_categorical_accuracy: 0.7281
# Epoch 7/50
# 41/41 - 51s - loss: 1.0789 - categorical_accuracy: 0.7101 - top_k_categorical_accuracy: 0.9551 - val_loss: 2.8095 - val_categorical_accuracy: 0.3991 - val_top_k_categorical_accuracy: 0.7310
# Epoch 8/50
# 41/41 - 47s - loss: 0.9736 - categorical_accuracy: 0.7247 - top_k_categorical_accuracy: 0.9653 - val_loss: 3.1187 - val_categorical_accuracy: 0.3743 - val_top_k_categorical_accuracy: 0.7295
# Epoch 9/50
# 41/41 - 48s - loss: 0.9710 - categorical_accuracy: 0.7408 - top_k_categorical_accuracy: 0.9624 - val_loss: 3.0825 - val_categorical_accuracy: 0.3670 - val_top_k_categorical_accuracy: 0.7383
# Epoch 10/50
# 41/41 - 46s - loss: 0.7337 - categorical_accuracy: 0.7887 - top_k_categorical_accuracy: 0.9722 - val_loss: 2.8371 - val_categorical_accuracy: 0.4181 - val_top_k_categorical_accuracy: 0.7471
# Epoch 11/50
# 41/41 - 47s - loss: 0.7011 - categorical_accuracy: 0.7916 - top_k_categorical_accuracy: 0.9732 - val_loss: 2.9631 - val_categorical_accuracy: 0.4108 - val_top_k_categorical_accuracy: 0.7222
# Epoch 12/50
# 41/41 - 46s - loss: 0.6128 - categorical_accuracy: 0.8219 - top_k_categorical_accuracy: 0.9771 - val_loss: 3.2964 - val_categorical_accuracy: 0.4020 - val_top_k_categorical_accuracy: 0.7178
# Epoch 13/50
# 41/41 - 50s - loss: 0.6466 - categorical_accuracy: 0.8053 - top_k_categorical_accuracy: 0.9824 - val_loss: 3.0046 - val_categorical_accuracy: 0.4167 - val_top_k_categorical_accuracy: 0.7295
# Epoch 14/50
# 41/41 - 47s - loss: 0.5293 - categorical_accuracy: 0.8306 - top_k_categorical_accuracy: 0.9883 - val_loss: 3.1646 - val_categorical_accuracy: 0.4284 - val_top_k_categorical_accuracy: 0.7325
# Epoch 15/50
# 41/41 - 48s - loss: 0.3768 - categorical_accuracy: 0.8804 - top_k_categorical_accuracy: 0.9927 - val_loss: 2.8922 - val_categorical_accuracy: 0.4211 - val_top_k_categorical_accuracy: 0.7632
# Epoch 16/50
# 41/41 - 47s - loss: 0.3950 - categorical_accuracy: 0.8707 - top_k_categorical_accuracy: 0.9922 - val_loss: 2.8712 - val_categorical_accuracy: 0.4503 - val_top_k_categorical_accuracy: 0.7617
# Epoch 17/50
# 41/41 - 48s - loss: 0.4592 - categorical_accuracy: 0.8511 - top_k_categorical_accuracy: 0.9907 - val_loss: 3.1849 - val_categorical_accuracy: 0.3991 - val_top_k_categorical_accuracy: 0.7368
# Epoch 18/50
# 41/41 - 48s - loss: 0.3077 - categorical_accuracy: 0.8960 - top_k_categorical_accuracy: 0.9980 - val_loss: 2.7654 - val_categorical_accuracy: 0.4298 - val_top_k_categorical_accuracy: 0.7646
# Epoch 19/50
# 41/41 - 47s - loss: 0.3477 - categorical_accuracy: 0.8829 - top_k_categorical_accuracy: 0.9937 - val_loss: 2.5741 - val_categorical_accuracy: 0.4664 - val_top_k_categorical_accuracy: 0.7822
# Epoch 20/50
# 41/41 - 50s - loss: 0.3821 - categorical_accuracy: 0.8716 - top_k_categorical_accuracy: 0.9946 - val_loss: 2.8650 - val_categorical_accuracy: 0.4430 - val_top_k_categorical_accuracy: 0.7719
# Epoch 21/50
# 41/41 - 47s - loss: 0.2816 - categorical_accuracy: 0.9068 - top_k_categorical_accuracy: 0.9976 - val_loss: 2.8237 - val_categorical_accuracy: 0.4576 - val_top_k_categorical_accuracy: 0.7661
# Epoch 22/50
# 41/41 - 51s - loss: 0.2397 - categorical_accuracy: 0.9112 - top_k_categorical_accuracy: 0.9976 - val_loss: 3.4471 - val_categorical_accuracy: 0.3889 - val_top_k_categorical_accuracy: 0.7500
# Epoch 23/50
# 41/41 - 49s - loss: 0.2476 - categorical_accuracy: 0.9190 - top_k_categorical_accuracy: 0.9980 - val_loss: 2.9662 - val_categorical_accuracy: 0.4430 - val_top_k_categorical_accuracy: 0.7705
# Epoch 24/50
# 41/41 - 47s - loss: 0.1854 - categorical_accuracy: 0.9375 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.3062 - val_categorical_accuracy: 0.4050 - val_top_k_categorical_accuracy: 0.7398
# Epoch 25/50
# 41/41 - 47s - loss: 0.1653 - categorical_accuracy: 0.9434 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.0014 - val_categorical_accuracy: 0.4459 - val_top_k_categorical_accuracy: 0.7588
# Epoch 26/50
# 41/41 - 49s - loss: 0.1777 - categorical_accuracy: 0.9395 - top_k_categorical_accuracy: 0.9990 - val_loss: 2.8665 - val_categorical_accuracy: 0.4474 - val_top_k_categorical_accuracy: 0.7778
# Epoch 27/50
# 41/41 - 46s - loss: 0.1993 - categorical_accuracy: 0.9317 - top_k_categorical_accuracy: 0.9985 - val_loss: 2.7469 - val_categorical_accuracy: 0.4693 - val_top_k_categorical_accuracy: 0.7865
# Epoch 28/50
# 41/41 - 50s - loss: 0.3009 - categorical_accuracy: 0.8951 - top_k_categorical_accuracy: 0.9976 - val_loss: 3.3849 - val_categorical_accuracy: 0.4342 - val_top_k_categorical_accuracy: 0.7471
# Epoch 29/50
# 41/41 - 47s - loss: 0.1725 - categorical_accuracy: 0.9419 - top_k_categorical_accuracy: 0.9985 - val_loss: 3.4008 - val_categorical_accuracy: 0.4094 - val_top_k_categorical_accuracy: 0.7529
# Epoch 30/50
# 41/41 - 47s - loss: 0.1695 - categorical_accuracy: 0.9366 - top_k_categorical_accuracy: 0.9990 - val_loss: 3.1349 - val_categorical_accuracy: 0.4459 - val_top_k_categorical_accuracy: 0.7719
# Epoch 31/50
# 41/41 - 46s - loss: 0.1834 - categorical_accuracy: 0.9375 - top_k_categorical_accuracy: 0.9990 - val_loss: 3.0471 - val_categorical_accuracy: 0.4561 - val_top_k_categorical_accuracy: 0.7661
# Epoch 32/50
# 41/41 - 48s - loss: 0.1202 - categorical_accuracy: 0.9614 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.9858 - val_categorical_accuracy: 0.4635 - val_top_k_categorical_accuracy: 0.7632
# Epoch 33/50
# 41/41 - 50s - loss: 0.1229 - categorical_accuracy: 0.9600 - top_k_categorical_accuracy: 0.9990 - val_loss: 2.8465 - val_categorical_accuracy: 0.4605 - val_top_k_categorical_accuracy: 0.7851
# Epoch 34/50
# 41/41 - 46s - loss: 0.0973 - categorical_accuracy: 0.9678 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.4345 - val_categorical_accuracy: 0.4254 - val_top_k_categorical_accuracy: 0.7456
# Epoch 35/50
# 41/41 - 47s - loss: 0.1424 - categorical_accuracy: 0.9434 - top_k_categorical_accuracy: 0.9995 - val_loss: 2.7722 - val_categorical_accuracy: 0.4912 - val_top_k_categorical_accuracy: 0.7982
# Epoch 36/50
# 41/41 - 47s - loss: 0.1054 - categorical_accuracy: 0.9639 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.1709 - val_categorical_accuracy: 0.4503 - val_top_k_categorical_accuracy: 0.7661
# Epoch 37/50
# 41/41 - 47s - loss: 0.1344 - categorical_accuracy: 0.9546 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.1936 - val_categorical_accuracy: 0.4430 - val_top_k_categorical_accuracy: 0.7515
# Epoch 38/50
# 41/41 - 47s - loss: 0.1181 - categorical_accuracy: 0.9556 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.0507 - val_categorical_accuracy: 0.4591 - val_top_k_categorical_accuracy: 0.7705
# Epoch 39/50
# 41/41 - 47s - loss: 0.0961 - categorical_accuracy: 0.9683 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.0443 - val_categorical_accuracy: 0.4503 - val_top_k_categorical_accuracy: 0.7705
# Epoch 40/50
# 41/41 - 46s - loss: 0.1104 - categorical_accuracy: 0.9619 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.0431 - val_categorical_accuracy: 0.4635 - val_top_k_categorical_accuracy: 0.7807
# Epoch 41/50
# 41/41 - 47s - loss: 0.1025 - categorical_accuracy: 0.9663 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.2695 - val_categorical_accuracy: 0.4342 - val_top_k_categorical_accuracy: 0.7705
# Epoch 42/50
# 41/41 - 46s - loss: 0.0725 - categorical_accuracy: 0.9766 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.0558 - val_categorical_accuracy: 0.4591 - val_top_k_categorical_accuracy: 0.7749
# Epoch 43/50
# 41/41 - 49s - loss: 0.0868 - categorical_accuracy: 0.9663 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.5041 - val_categorical_accuracy: 0.4284 - val_top_k_categorical_accuracy: 0.7427
# Epoch 44/50
# 41/41 - 47s - loss: 0.0877 - categorical_accuracy: 0.9776 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.0537 - val_categorical_accuracy: 0.4576 - val_top_k_categorical_accuracy: 0.7865
# Epoch 45/50
# 41/41 - 46s - loss: 0.0747 - categorical_accuracy: 0.9795 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.2624 - val_categorical_accuracy: 0.4591 - val_top_k_categorical_accuracy: 0.7500
# Epoch 46/50
# 41/41 - 52s - loss: 0.0822 - categorical_accuracy: 0.9751 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.4800 - val_categorical_accuracy: 0.4357 - val_top_k_categorical_accuracy: 0.7632
# Epoch 47/50
# 41/41 - 49s - loss: 0.0852 - categorical_accuracy: 0.9741 - top_k_categorical_accuracy: 0.9990 - val_loss: 3.3386 - val_categorical_accuracy: 0.4415 - val_top_k_categorical_accuracy: 0.7602
# Epoch 48/50
# 41/41 - 46s - loss: 0.0952 - categorical_accuracy: 0.9693 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.4854 - val_categorical_accuracy: 0.4181 - val_top_k_categorical_accuracy: 0.7749
# Epoch 49/50
# 41/41 - 46s - loss: 0.1216 - categorical_accuracy: 0.9624 - top_k_categorical_accuracy: 0.9995 - val_loss: 2.8841 - val_categorical_accuracy: 0.4766 - val_top_k_categorical_accuracy: 0.8041
# Epoch 50/50
# 41/41 - 47s - loss: 0.1805 - categorical_accuracy: 0.9400 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.4230 - val_categorical_accuracy: 0.4342 - val_top_k_categorical_accuracy: 0.7880

# %%
def smooth(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['loss']),color="Blue")
plt.plot(history.history['loss'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_loss']),color="Red")
plt.plot(history.history['val_loss'],alpha=0.2,color="Red")
plt.ylabel('loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.yscale("log")
plt.legend(['train', 'train real','validation', 'validation real'], loc='upper right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['categorical_accuracy']),color="Blue")
plt.plot(history.history['categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_categorical_accuracy']),color="Red")
plt.plot(history.history['val_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()

# %%
import pandas as pd
    
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histDense201.csv")

# %%
# %whos
# Out:
# Variable                Type                  Data/Info
# -------------------------------------------------------
# Model                   type                  <class 'tensorflow.python<...>s.engine.training.Model'>
# PIL                     module                <module 'PIL' from '/usr/<...>ackages/PIL/__init__.py'>
# ax                      AxesSubplot           AxesSubplot(0.125,0.125;0.775x0.755)
# b                       function              <function keras_modules_i<...>rapper at 0x7f78200828c8>
# base                    Model                 <tensorflow.python.keras.<...>object at 0x7f7801dafda0>
# call_list               list                  n=6
# classification_report   function              <function classification_<...>report at 0x7f78150ba488>
# confusion_matrix        function              <function confusion_matrix at 0x7f78150b4bf8>
# fig                     Figure                Figure(864x504)
# history                 History               <tensorflow.python.keras.<...>object at 0x7f780191eeb8>
# image                   DeprecationWrapper    <module 'tensorflow.pytho<...>ssing/image/__init__.py'>
# layers                  DeprecationWrapper    <module 'tensorflow.pytho<...>eras/layers/__init__.py'>
# load_model              function              <function load_model at 0x7f7820943d90>
# mask_unused_gpus        function              <function mask_unused_gpus at 0x7f7862f13ea0>
# model                   Model                 <tensorflow.python.keras.<...>object at 0x7f7862f4def0>
# models                  DeprecationWrapper    <module 'tensorflow.keras<...>eras/models/__init__.py'>
# np                      module                <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# optimizers              DeprecationWrapper    <module 'tensorflow.pytho<...>/optimizers/__init__.py'>
# os                      module                <module 'os' from '/usr/lib/python3.6/os.py'>
# pd                      module                <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# plt                     module                <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# predictions             Tensor                Tensor("dense/Softmax:0",<...>e=(?, 16), dtype=float32)
# regularizers            DeprecationWrapper    <module 'tensorflow.pytho<...>egularizers/__init__.py'>
# smooth                  function              <function smooth at 0x7f78018b0840>
# sp                      module                <module 'subprocess' from<...>python3.6/subprocess.py'>
# test                    DirectoryIterator     <keras_preprocessing.imag<...>object at 0x7f7862f88128>
# testgen                 ImageDataGenerator    <tensorflow.python.keras.<...>object at 0x7f780196f198>
# tf                      DeprecationWrapper    <module 'tensorflow' from<...>/tensorflow/__init__.py'>
# ticker                  module                <module 'matplotlib.ticke<...>es/matplotlib/ticker.py'>
# to_categorical          function              <function to_categorical at 0x7f782012a620>
# train                   DirectoryIterator     <keras_preprocessing.imag<...>object at 0x7f780196f208>
# traingen                ImageDataGenerator    <tensorflow.python.keras.<...>object at 0x7f780196f160>
# val                     DirectoryIterator     <keras_preprocessing.imag<...>object at 0x7f7801978470>
# validationgen           ImageDataGenerator    <tensorflow.python.keras.<...>object at 0x7f780196f128>
# x                       Tensor                Tensor("max_pool/Max:0", <...>(?, 1920), dtype=float32)

# %%
d=pd.read_csv("histDense169.csv")
d1=pd.read_csv("histDense169-1.csv")
d2=pd.read_csv("histDense169-2.csv")
d3=pd.read_csv("histDense169-3.csv")
d4=pd.read_csv("histDense169-4.csv")
