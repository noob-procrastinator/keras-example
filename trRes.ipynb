# %%
from tensorflow.keras.applications.resnet50 import ResNet50 as b
import numpy as np
import pandas as pd
from matplotlib import ticker
#import seaborn as sn
import PIL
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
import subprocess as sp
import os

def mask_unused_gpus(leave_unmasked=1):
  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"

  try:
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    available_gpus = [i for i, x in enumerate(memory_free_values) if x > ACCEPTABLE_AVAILABLE_MEMORY]

    if len(available_gpus) < leave_unmasked: raise ValueError('Found only %d usable GPUs in the system' % len(available_gpus))
    os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, available_gpus[:leave_unmasked]))
  except Exception as e:
    print('"nvidia-smi" is probably not installed. GPUs are not masked', e)

mask_unused_gpus()

# %%
traingen = image.ImageDataGenerator(rescale=1./255)#,rotation_range=10,width_shift_range=20,height_shift_range=10,shear_range=10,horizontal_flip=True,vertical_flip=True)
validationgen = image.ImageDataGenerator(rescale=1./255)
testgen = image.ImageDataGenerator(rescale=1./255)

train = traingen.flow_from_directory("train",target_size=(500, 825), batch_size=50, shuffle=True)
val = validationgen.flow_from_directory("validation",target_size=(500, 825), batch_size=56, shuffle=False)
test=testgen.flow_from_directory("test",target_size=(500, 825), batch_size=32, shuffle=False)
# Out:
# Found 2049 images belonging to 16 classes.
# Found 684 images belonging to 16 classes.
# Found 683 images belonging to 16 classes.

# %%
call_list = [tf.keras.callbacks.ModelCheckpoint(
                 filepath='./Res/trRes-{epoch:02d}-{val_categorical_accuracy:.4f}-{categorical_accuracy:.4f}.h5',
                 monitor='val_categorical_accuracy',
                 save_best_only=False,),
             
             tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta=0.001,patience=4,),
             tf.keras.callbacks.EarlyStopping(monitor='categorical_accuracy',min_delta=0.0005,patience=6,),
             tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy',min_delta=0.0005,patience=8,),
             
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_delta=0.005,),
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',factor=0.5,patience=4,min_delta=0.005,)
            ]


base = b(include_top=False,
                weights="imagenet",
                input_shape=(500, 825, 3),
               pooling="max")

x = base.output
#x = layers.Dropout(0.5)(x)
#x = layers.GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
#x = layers.Dense(16, activation='selu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
predictions = layers.Dense(16, activation='softmax')(x)#, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)

model = Model(inputs=base.input, outputs=predictions)

# this is the model we will train

for layer in base.layers:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=["categorical_accuracy","top_k_categorical_accuracy"])



history = model.fit_generator(train,
                              #callbacks=call_list,
                              steps_per_epoch=np.ceil(2049/50),
                              epochs=50,
                              verbose=2,
                              validation_data= val,
                              validation_steps=np.ceil(684/56)
                              )


hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histRespre.csv")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1103 15:53:27.351110 140573158696768 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/50
# 41/41 - 49s - loss: 13.9709 - categorical_accuracy: 0.2001 - top_k_categorical_accuracy: 0.5647 - val_loss: 7.6096 - val_categorical_accuracy: 0.0702 - val_top_k_categorical_accuracy: 0.3406
# Epoch 2/50
# 41/41 - 44s - loss: 5.1397 - categorical_accuracy: 0.4617 - top_k_categorical_accuracy: 0.8282 - val_loss: 7.5327 - val_categorical_accuracy: 0.0789 - val_top_k_categorical_accuracy: 0.3392
# Epoch 3/50
# 41/41 - 45s - loss: 3.3194 - categorical_accuracy: 0.5813 - top_k_categorical_accuracy: 0.9112 - val_loss: 8.2270 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3348
# Epoch 4/50
# 41/41 - 44s - loss: 3.0447 - categorical_accuracy: 0.6120 - top_k_categorical_accuracy: 0.9244 - val_loss: 7.6903 - val_categorical_accuracy: 0.0775 - val_top_k_categorical_accuracy: 0.3450
# Epoch 5/50
# 41/41 - 44s - loss: 2.4415 - categorical_accuracy: 0.6701 - top_k_categorical_accuracy: 0.9405 - val_loss: 8.5948 - val_categorical_accuracy: 0.0789 - val_top_k_categorical_accuracy: 0.3070
# Epoch 6/50
# 41/41 - 44s - loss: 1.7579 - categorical_accuracy: 0.7399 - top_k_categorical_accuracy: 0.9702 - val_loss: 8.9003 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3099
# Epoch 7/50
# 41/41 - 44s - loss: 1.7585 - categorical_accuracy: 0.7384 - top_k_categorical_accuracy: 0.9673 - val_loss: 8.4698 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3085
# Epoch 8/50
# 41/41 - 43s - loss: 1.5026 - categorical_accuracy: 0.7716 - top_k_categorical_accuracy: 0.9829 - val_loss: 9.5038 - val_categorical_accuracy: 0.0702 - val_top_k_categorical_accuracy: 0.3246
# Epoch 9/50
# 41/41 - 44s - loss: 1.0678 - categorical_accuracy: 0.8136 - top_k_categorical_accuracy: 0.9868 - val_loss: 9.9513 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3129
# Epoch 10/50
# 41/41 - 45s - loss: 0.8520 - categorical_accuracy: 0.8385 - top_k_categorical_accuracy: 0.9927 - val_loss: 9.6284 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3173
# Epoch 11/50
# 41/41 - 45s - loss: 0.7877 - categorical_accuracy: 0.8492 - top_k_categorical_accuracy: 0.9932 - val_loss: 8.8424 - val_categorical_accuracy: 0.0629 - val_top_k_categorical_accuracy: 0.3216
# Epoch 12/50
# 41/41 - 44s - loss: 0.8425 - categorical_accuracy: 0.8433 - top_k_categorical_accuracy: 0.9898 - val_loss: 8.8554 - val_categorical_accuracy: 0.0687 - val_top_k_categorical_accuracy: 0.3099
# Epoch 13/50
# 41/41 - 44s - loss: 0.6855 - categorical_accuracy: 0.8619 - top_k_categorical_accuracy: 0.9917 - val_loss: 7.8113 - val_categorical_accuracy: 0.0863 - val_top_k_categorical_accuracy: 0.3129
# Epoch 14/50
# 41/41 - 43s - loss: 0.5697 - categorical_accuracy: 0.8755 - top_k_categorical_accuracy: 0.9961 - val_loss: 9.3812 - val_categorical_accuracy: 0.0716 - val_top_k_categorical_accuracy: 0.3114
# Epoch 15/50
# 41/41 - 44s - loss: 0.5512 - categorical_accuracy: 0.8990 - top_k_categorical_accuracy: 0.9927 - val_loss: 10.1292 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3216
# Epoch 16/50
# 41/41 - 43s - loss: 0.4856 - categorical_accuracy: 0.9009 - top_k_categorical_accuracy: 0.9951 - val_loss: 9.3317 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3085
# Epoch 17/50
# 41/41 - 43s - loss: 0.2957 - categorical_accuracy: 0.9248 - top_k_categorical_accuracy: 0.9985 - val_loss: 9.1297 - val_categorical_accuracy: 0.0804 - val_top_k_categorical_accuracy: 0.3099
# Epoch 18/50
# 41/41 - 42s - loss: 0.3301 - categorical_accuracy: 0.9151 - top_k_categorical_accuracy: 0.9980 - val_loss: 10.0508 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3158
# Epoch 19/50
# 41/41 - 43s - loss: 0.5138 - categorical_accuracy: 0.9117 - top_k_categorical_accuracy: 0.9927 - val_loss: 9.8439 - val_categorical_accuracy: 0.0789 - val_top_k_categorical_accuracy: 0.3114
# Epoch 20/50
# 41/41 - 43s - loss: 0.1864 - categorical_accuracy: 0.9458 - top_k_categorical_accuracy: 0.9995 - val_loss: 9.4927 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3099
# Epoch 21/50
# 41/41 - 43s - loss: 0.2078 - categorical_accuracy: 0.9444 - top_k_categorical_accuracy: 0.9990 - val_loss: 9.5165 - val_categorical_accuracy: 0.0804 - val_top_k_categorical_accuracy: 0.3099
# Epoch 24/50
# 41/41 - 43s - loss: 0.1978 - categorical_accuracy: 0.9488 - top_k_categorical_accuracy: 0.9995 - val_loss: 10.7285 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3099
# Epoch 25/50
# 41/41 - 43s - loss: 0.1126 - categorical_accuracy: 0.9678 - top_k_categorical_accuracy: 0.9995 - val_loss: 10.7634 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3187
# Epoch 26/50
# 41/41 - 40s - loss: 0.2192 - categorical_accuracy: 0.9507 - top_k_categorical_accuracy: 1.0000 - val_loss: 10.5523 - val_categorical_accuracy: 0.0760 - val_top_k_categorical_accuracy: 0.3304
# Epoch 30/50
# 41/41 - 40s - loss: 0.0819 - categorical_accuracy: 0.9736 - top_k_categorical_accuracy: 1.0000 - val_loss: 9.9959 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3143
# Epoch 31/50
# 41/41 - 40s - loss: 0.1302 - categorical_accuracy: 0.9629 - top_k_categorical_accuracy: 1.0000 - val_loss: 10.8472 - val_categorical_accuracy: 0.0716 - val_top_k_categorical_accuracy: 0.3289
# Epoch 32/50
# 41/41 - 40s - loss: 0.3639 - categorical_accuracy: 0.9229 - top_k_categorical_accuracy: 0.9976 - val_loss: 10.5776 - val_categorical_accuracy: 0.0863 - val_top_k_categorical_accuracy: 0.3216
# Epoch 33/50
# 41/41 - 40s - loss: 0.3184 - categorical_accuracy: 0.9234 - top_k_categorical_accuracy: 0.9995 - val_loss: 10.0434 - val_categorical_accuracy: 0.0863 - val_top_k_categorical_accuracy: 0.3129
# Epoch 34/50
# 41/41 - 40s - loss: 0.3040 - categorical_accuracy: 0.9385 - top_k_categorical_accuracy: 0.9985 - val_loss: 11.9361 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3304
# Epoch 35/50
# 41/41 - 39s - loss: 0.3270 - categorical_accuracy: 0.9351 - top_k_categorical_accuracy: 0.9980 - val_loss: 10.8713 - val_categorical_accuracy: 0.0877 - val_top_k_categorical_accuracy: 0.3246
# Epoch 36/50
# 41/41 - 40s - loss: 0.2284 - categorical_accuracy: 0.9531 - top_k_categorical_accuracy: 0.9995 - val_loss: 11.4912 - val_categorical_accuracy: 0.0746 - val_top_k_categorical_accuracy: 0.3231
# Epoch 37/50
# 41/41 - 40s - loss: 0.0912 - categorical_accuracy: 0.9766 - top_k_categorical_accuracy: 1.0000 - val_loss: 10.3760 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3319
# Epoch 38/50
# 41/41 - 40s - loss: 0.1371 - categorical_accuracy: 0.9644 - top_k_categorical_accuracy: 1.0000 - val_loss: 11.4691 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3187
# Epoch 39/50
# 41/41 - 40s - loss: 0.0784 - categorical_accuracy: 0.9780 - top_k_categorical_accuracy: 1.0000 - val_loss: 12.2346 - val_categorical_accuracy: 0.0673 - val_top_k_categorical_accuracy: 0.3304
# Epoch 43/50
# 41/41 - 40s - loss: 0.1427 - categorical_accuracy: 0.9688 - top_k_categorical_accuracy: 0.9995 - val_loss: 11.5638 - val_categorical_accuracy: 0.0760 - val_top_k_categorical_accuracy: 0.3319
# Epoch 44/50
# 41/41 - 39s - loss: 0.0976 - categorical_accuracy: 0.9780 - top_k_categorical_accuracy: 1.0000 - val_loss: 12.0141 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3319
# Epoch 45/50
# 41/41 - 38s - loss: 0.1865 - categorical_accuracy: 0.9624 - top_k_categorical_accuracy: 0.9990 - val_loss: 13.3396 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3319
# Epoch 46/50
# 41/41 - 38s - loss: 0.2063 - categorical_accuracy: 0.9536 - top_k_categorical_accuracy: 0.9990 - val_loss: 11.2178 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3319
# Epoch 47/50
# 41/41 - 38s - loss: 0.0967 - categorical_accuracy: 0.9776 - top_k_categorical_accuracy: 1.0000 - val_loss: 11.9007 - val_categorical_accuracy: 0.0658 - val_top_k_categorical_accuracy: 0.3289
# Epoch 48/50
# 41/41 - 38s - loss: 0.1092 - categorical_accuracy: 0.9746 - top_k_categorical_accuracy: 0.9995 - val_loss: 12.8497 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3319
# Epoch 49/50
# 41/41 - 37s - loss: 0.1999 - categorical_accuracy: 0.9619 - top_k_categorical_accuracy: 0.9990 - val_loss: 10.6052 - val_categorical_accuracy: 0.0731 - val_top_k_categorical_accuracy: 0.3158
# Epoch 50/50
# 41/41 - 37s - loss: 0.1154 - categorical_accuracy: 0.9697 - top_k_categorical_accuracy: 1.0000 - val_loss: 13.5559 - val_categorical_accuracy: 0.0643 - val_top_k_categorical_accuracy: 0.3173

# %%
def smooth(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['loss']),color="Blue")
plt.plot(history.history['loss'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_loss']),color="Red")
plt.plot(history.history['val_loss'],alpha=0.2,color="Red")
plt.ylabel('loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train', 'train real','validation', 'validation real'], loc='upper right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['categorical_accuracy']),color="Blue")
plt.plot(history.history['categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_categorical_accuracy']),color="Red")
plt.plot(history.history['val_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()
