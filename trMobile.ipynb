# %%
from tensorflow.keras.applications import MobileNetV2 as b # .mobilenet_v2.MobileNetV2
import numpy as np
import pandas as pd
from matplotlib import ticker
#import seaborn as sn
import PIL
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
import subprocess as sp
import os

def mask_unused_gpus(leave_unmasked=1):
  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"

  try:
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    available_gpus = [i for i, x in enumerate(memory_free_values) if x > ACCEPTABLE_AVAILABLE_MEMORY]

    if len(available_gpus) < leave_unmasked: raise ValueError('Found only %d usable GPUs in the system' % len(available_gpus))
    os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, available_gpus[:leave_unmasked]))
  except Exception as e:
    print('"nvidia-smi" is probably not installed. GPUs are not masked', e)

mask_unused_gpus()

# %%
traingen = image.ImageDataGenerator(rescale=1./255)#,rotation_range=10,width_shift_range=20,height_shift_range=10,shear_range=10,horizontal_flip=True,vertical_flip=True)
validationgen = image.ImageDataGenerator(rescale=1./255)
testgen = image.ImageDataGenerator(rescale=1./255)

train = traingen.flow_from_directory("train",target_size=(500, 825), batch_size=50, shuffle=True)
val = validationgen.flow_from_directory("validation",target_size=(500, 825), batch_size=56, shuffle=False)
test=testgen.flow_from_directory("test",target_size=(500, 825), batch_size=32, shuffle=False)
# Out:
# Found 2049 images belonging to 16 classes.
# Found 684 images belonging to 16 classes.
# Found 683 images belonging to 16 classes.

# %%
call_list = [tf.keras.callbacks.ModelCheckpoint(
                 filepath='./Mobile/trM-{epoch:02d}-{val_categorical_accuracy:.4f}-{categorical_accuracy:.4f}.h5',
                 monitor='val_categorical_accuracy',
                 save_best_only=False,),
             
             tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta=0.001,patience=4,),
             tf.keras.callbacks.EarlyStopping(monitor='categorical_accuracy',min_delta=0.0005,patience=6,),
             tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy',min_delta=0.0005,patience=8,),
             
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_delta=0.005,),
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',factor=0.5,patience=4,min_delta=0.005,)
            ]

    
    
it = tf.keras.layers.Input(shape=(500, 825, 3))    


base = b(include_top=False,
                    weights="imagenet",
                    input_tensor=it,
                   pooling="max")

x = base.output
#x = layers.Dropout(0.5)(x)
#x = layers.GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
#x = layers.Dense(16, activation='selu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
predictions = layers.Dense(16, activation='softmax')(x)#, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)

model = Model(inputs=base.input, outputs=predictions)

    # this is the model we will train

for layer in base.layers:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(), 
                  loss='categorical_crossentropy', 
                  metrics=["categorical_accuracy","top_k_categorical_accuracy"])
    
    
history = model.fit_generator(train,
                              #callbacks=call_list,
                              steps_per_epoch=np.ceil(2049/50),
                              epochs=50,
                              verbose=2,
                              validation_data= val,
                              validation_steps=np.ceil(684/56)
                              )
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histMobileV2pre.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet_v2.py:306: UserWarning: MobileNet shape is undefined. Weights for input shape(224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'
# WARNING: Logging before flag parsing goes to stderr.
# W1103 19:37:07.586275 140020078298944 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 2s 0us/step
# Epoch 1/50
# 41/41 - 51s - loss: 7.1698 - categorical_accuracy: 0.0815 - top_k_categorical_accuracy: 0.3558 - val_loss: 5.1300 - val_categorical_accuracy: 0.0965 - val_top_k_categorical_accuracy: 0.4094
# Epoch 2/50
# 41/41 - 35s - loss: 3.7906 - categorical_accuracy: 0.1020 - top_k_categorical_accuracy: 0.4300 - val_loss: 4.8946 - val_categorical_accuracy: 0.1170 - val_top_k_categorical_accuracy: 0.4298
# Epoch 3/50
# 41/41 - 35s - loss: 3.3825 - categorical_accuracy: 0.1479 - top_k_categorical_accuracy: 0.5012 - val_loss: 4.4733 - val_categorical_accuracy: 0.1462 - val_top_k_categorical_accuracy: 0.4839
# Epoch 4/50
# 41/41 - 36s - loss: 3.1766 - categorical_accuracy: 0.1894 - top_k_categorical_accuracy: 0.5515 - val_loss: 4.7465 - val_categorical_accuracy: 0.1711 - val_top_k_categorical_accuracy: 0.4942
# Epoch 5/50
# 41/41 - 36s - loss: 2.9209 - categorical_accuracy: 0.2274 - top_k_categorical_accuracy: 0.6154 - val_loss: 4.8415 - val_categorical_accuracy: 0.1667 - val_top_k_categorical_accuracy: 0.5351
# Epoch 6/50
# 41/41 - 37s - loss: 2.7372 - categorical_accuracy: 0.2631 - top_k_categorical_accuracy: 0.6496 - val_loss: 4.6992 - val_categorical_accuracy: 0.1798 - val_top_k_categorical_accuracy: 0.5468
# Epoch 7/50
# 41/41 - 38s - loss: 2.4642 - categorical_accuracy: 0.2992 - top_k_categorical_accuracy: 0.7106 - val_loss: 4.3057 - val_categorical_accuracy: 0.2208 - val_top_k_categorical_accuracy: 0.5497
# Epoch 8/50
# 41/41 - 38s - loss: 2.5173 - categorical_accuracy: 0.3114 - top_k_categorical_accuracy: 0.7077 - val_loss: 4.7119 - val_categorical_accuracy: 0.2120 - val_top_k_categorical_accuracy: 0.5365
# Epoch 9/50
# 41/41 - 39s - loss: 2.4255 - categorical_accuracy: 0.3470 - top_k_categorical_accuracy: 0.7330 - val_loss: 4.2677 - val_categorical_accuracy: 0.2588 - val_top_k_categorical_accuracy: 0.6023
# Epoch 10/50
# 41/41 - 39s - loss: 2.4232 - categorical_accuracy: 0.3612 - top_k_categorical_accuracy: 0.7389 - val_loss: 5.0719 - val_categorical_accuracy: 0.2281 - val_top_k_categorical_accuracy: 0.5380
# Epoch 11/50
# 41/41 - 40s - loss: 2.1184 - categorical_accuracy: 0.4178 - top_k_categorical_accuracy: 0.7818 - val_loss: 4.4620 - val_categorical_accuracy: 0.2471 - val_top_k_categorical_accuracy: 0.5906
# Epoch 12/50
# 41/41 - 40s - loss: 1.9649 - categorical_accuracy: 0.4324 - top_k_categorical_accuracy: 0.8048 - val_loss: 5.1435 - val_categorical_accuracy: 0.2120 - val_top_k_categorical_accuracy: 0.5687
# Epoch 13/50
# 41/41 - 41s - loss: 1.8153 - categorical_accuracy: 0.4563 - top_k_categorical_accuracy: 0.8394 - val_loss: 4.6430 - val_categorical_accuracy: 0.2515 - val_top_k_categorical_accuracy: 0.5980
# Epoch 14/50
# 41/41 - 40s - loss: 1.9375 - categorical_accuracy: 0.4451 - top_k_categorical_accuracy: 0.8228 - val_loss: 4.4461 - val_categorical_accuracy: 0.2822 - val_top_k_categorical_accuracy: 0.6111
# Epoch 15/50
# 41/41 - 41s - loss: 1.7872 - categorical_accuracy: 0.4846 - top_k_categorical_accuracy: 0.8355 - val_loss: 5.3474 - val_categorical_accuracy: 0.2412 - val_top_k_categorical_accuracy: 0.5980
# Epoch 16/50
# 41/41 - 40s - loss: 1.7480 - categorical_accuracy: 0.4890 - top_k_categorical_accuracy: 0.8453 - val_loss: 4.7170 - val_categorical_accuracy: 0.2573 - val_top_k_categorical_accuracy: 0.6213
# Epoch 17/50
# 41/41 - 40s - loss: 1.6577 - categorical_accuracy: 0.5154 - top_k_categorical_accuracy: 0.8624 - val_loss: 4.8742 - val_categorical_accuracy: 0.2661 - val_top_k_categorical_accuracy: 0.6023
# Epoch 18/50
# 41/41 - 41s - loss: 1.7592 - categorical_accuracy: 0.4900 - top_k_categorical_accuracy: 0.8477 - val_loss: 4.6666 - val_categorical_accuracy: 0.2763 - val_top_k_categorical_accuracy: 0.5965
# Epoch 19/50
# 41/41 - 41s - loss: 1.6790 - categorical_accuracy: 0.5339 - top_k_categorical_accuracy: 0.8555 - val_loss: 4.9642 - val_categorical_accuracy: 0.2573 - val_top_k_categorical_accuracy: 0.6082
# Epoch 20/50
# 41/41 - 40s - loss: 1.6560 - categorical_accuracy: 0.5266 - top_k_categorical_accuracy: 0.8604 - val_loss: 4.6797 - val_categorical_accuracy: 0.2675 - val_top_k_categorical_accuracy: 0.6477
# Epoch 21/50
# 41/41 - 40s - loss: 1.4385 - categorical_accuracy: 0.5730 - top_k_categorical_accuracy: 0.8858 - val_loss: 4.8389 - val_categorical_accuracy: 0.2661 - val_top_k_categorical_accuracy: 0.6345
# Epoch 22/50
# 41/41 - 41s - loss: 1.4279 - categorical_accuracy: 0.5666 - top_k_categorical_accuracy: 0.8882 - val_loss: 4.8156 - val_categorical_accuracy: 0.2792 - val_top_k_categorical_accuracy: 0.6082
# Epoch 23/50
# 41/41 - 41s - loss: 1.4902 - categorical_accuracy: 0.5495 - top_k_categorical_accuracy: 0.8858 - val_loss: 5.2417 - val_categorical_accuracy: 0.2734 - val_top_k_categorical_accuracy: 0.6038
# Epoch 24/50
# 41/41 - 41s - loss: 1.3678 - categorical_accuracy: 0.5939 - top_k_categorical_accuracy: 0.9097 - val_loss: 5.0200 - val_categorical_accuracy: 0.2734 - val_top_k_categorical_accuracy: 0.6023
# Epoch 25/50
# 41/41 - 40s - loss: 1.5499 - categorical_accuracy: 0.5534 - top_k_categorical_accuracy: 0.8834 - val_loss: 5.9168 - val_categorical_accuracy: 0.2500 - val_top_k_categorical_accuracy: 0.5556
# Epoch 26/50
# 41/41 - 41s - loss: 1.3550 - categorical_accuracy: 0.5905 - top_k_categorical_accuracy: 0.9029 - val_loss: 5.2194 - val_categorical_accuracy: 0.2749 - val_top_k_categorical_accuracy: 0.5892
# Epoch 27/50
# 41/41 - 41s - loss: 1.3407 - categorical_accuracy: 0.5983 - top_k_categorical_accuracy: 0.9039 - val_loss: 5.0951 - val_categorical_accuracy: 0.2675 - val_top_k_categorical_accuracy: 0.6404
# Epoch 28/50
# 41/41 - 41s - loss: 1.2940 - categorical_accuracy: 0.6052 - top_k_categorical_accuracy: 0.9092 - val_loss: 5.2292 - val_categorical_accuracy: 0.2719 - val_top_k_categorical_accuracy: 0.6345
# Epoch 29/50
# 41/41 - 41s - loss: 1.3554 - categorical_accuracy: 0.5886 - top_k_categorical_accuracy: 0.9107 - val_loss: 5.5222 - val_categorical_accuracy: 0.2836 - val_top_k_categorical_accuracy: 0.5950
# Epoch 30/50
# 41/41 - 41s - loss: 1.1915 - categorical_accuracy: 0.6320 - top_k_categorical_accuracy: 0.9273 - val_loss: 5.5074 - val_categorical_accuracy: 0.2763 - val_top_k_categorical_accuracy: 0.6184
# Epoch 31/50
# 41/41 - 41s - loss: 1.1436 - categorical_accuracy: 0.6325 - top_k_categorical_accuracy: 0.9292 - val_loss: 5.5397 - val_categorical_accuracy: 0.2719 - val_top_k_categorical_accuracy: 0.6067
# Epoch 32/50
# 41/41 - 40s - loss: 1.3135 - categorical_accuracy: 0.6140 - top_k_categorical_accuracy: 0.9126 - val_loss: 4.4943 - val_categorical_accuracy: 0.3231 - val_top_k_categorical_accuracy: 0.6491
# Epoch 33/50
# 41/41 - 40s - loss: 1.2651 - categorical_accuracy: 0.6159 - top_k_categorical_accuracy: 0.9190 - val_loss: 5.2592 - val_categorical_accuracy: 0.2792 - val_top_k_categorical_accuracy: 0.6257
# Epoch 34/50
# 41/41 - 41s - loss: 1.1491 - categorical_accuracy: 0.6374 - top_k_categorical_accuracy: 0.9258 - val_loss: 5.3217 - val_categorical_accuracy: 0.2763 - val_top_k_categorical_accuracy: 0.6345
# Epoch 35/50
# 41/41 - 40s - loss: 1.3578 - categorical_accuracy: 0.6115 - top_k_categorical_accuracy: 0.8985 - val_loss: 5.5937 - val_categorical_accuracy: 0.2909 - val_top_k_categorical_accuracy: 0.6038
# Epoch 36/50
# 41/41 - 40s - loss: 1.2248 - categorical_accuracy: 0.6349 - top_k_categorical_accuracy: 0.9175 - val_loss: 5.0661 - val_categorical_accuracy: 0.2953 - val_top_k_categorical_accuracy: 0.6301
# Epoch 37/50
# 41/41 - 41s - loss: 1.1443 - categorical_accuracy: 0.6545 - top_k_categorical_accuracy: 0.9287 - val_loss: 5.7556 - val_categorical_accuracy: 0.2749 - val_top_k_categorical_accuracy: 0.6023
# Epoch 38/50
# 41/41 - 41s - loss: 1.1490 - categorical_accuracy: 0.6550 - top_k_categorical_accuracy: 0.9239 - val_loss: 5.6286 - val_categorical_accuracy: 0.2822 - val_top_k_categorical_accuracy: 0.6140
# Epoch 39/50
# 41/41 - 41s - loss: 1.0430 - categorical_accuracy: 0.6779 - top_k_categorical_accuracy: 0.9478 - val_loss: 5.4976 - val_categorical_accuracy: 0.2953 - val_top_k_categorical_accuracy: 0.6213
# Epoch 40/50
# 41/41 - 40s - loss: 1.1513 - categorical_accuracy: 0.6647 - top_k_categorical_accuracy: 0.9283 - val_loss: 5.7103 - val_categorical_accuracy: 0.3056 - val_top_k_categorical_accuracy: 0.6009
# Epoch 41/50
# 41/41 - 41s - loss: 0.9573 - categorical_accuracy: 0.6964 - top_k_categorical_accuracy: 0.9492 - val_loss: 5.1639 - val_categorical_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.6213
# Epoch 42/50
# 41/41 - 40s - loss: 1.0439 - categorical_accuracy: 0.6847 - top_k_categorical_accuracy: 0.9409 - val_loss: 5.8633 - val_categorical_accuracy: 0.2924 - val_top_k_categorical_accuracy: 0.6111
# Epoch 43/50
# 41/41 - 41s - loss: 1.0856 - categorical_accuracy: 0.6789 - top_k_categorical_accuracy: 0.9336 - val_loss: 5.4053 - val_categorical_accuracy: 0.3070 - val_top_k_categorical_accuracy: 0.6330
# Epoch 44/50
# 41/41 - 41s - loss: 1.0357 - categorical_accuracy: 0.6828 - top_k_categorical_accuracy: 0.9424 - val_loss: 5.4110 - val_categorical_accuracy: 0.2895 - val_top_k_categorical_accuracy: 0.6520
# Epoch 45/50
# 41/41 - 41s - loss: 0.9508 - categorical_accuracy: 0.7028 - top_k_categorical_accuracy: 0.9507 - val_loss: 5.6397 - val_categorical_accuracy: 0.2909 - val_top_k_categorical_accuracy: 0.6316
# Epoch 46/50
# 41/41 - 40s - loss: 0.9938 - categorical_accuracy: 0.6916 - top_k_categorical_accuracy: 0.9473 - val_loss: 6.0017 - val_categorical_accuracy: 0.2909 - val_top_k_categorical_accuracy: 0.6243
# Epoch 47/50
# 41/41 - 41s - loss: 1.0357 - categorical_accuracy: 0.6881 - top_k_categorical_accuracy: 0.9453 - val_loss: 5.6441 - val_categorical_accuracy: 0.2880 - val_top_k_categorical_accuracy: 0.6199
# Epoch 48/50
# 41/41 - 41s - loss: 0.9589 - categorical_accuracy: 0.7072 - top_k_categorical_accuracy: 0.9468 - val_loss: 5.3822 - val_categorical_accuracy: 0.3041 - val_top_k_categorical_accuracy: 0.6345
# Epoch 49/50
# 41/41 - 41s - loss: 1.2117 - categorical_accuracy: 0.6491 - top_k_categorical_accuracy: 0.9239 - val_loss: 6.6821 - val_categorical_accuracy: 0.2763 - val_top_k_categorical_accuracy: 0.5819
# Epoch 50/50
# 41/41 - 40s - loss: 0.9006 - categorical_accuracy: 0.7184 - top_k_categorical_accuracy: 0.9497 - val_loss: 6.0190 - val_categorical_accuracy: 0.2749 - val_top_k_categorical_accuracy: 0.6140

# %%
def smooth(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['loss']),color="Blue")
plt.plot(history.history['loss'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_loss']),color="Red")
plt.plot(history.history['val_loss'],alpha=0.2,color="Red")
plt.ylabel('loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train', 'train real','validation', 'validation real'], loc='upper right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['categorical_accuracy']),color="Blue")
plt.plot(history.history['categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_categorical_accuracy']),color="Red")
plt.plot(history.history['val_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()

# %%
import pandas as pd
    
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histMobileV2.csv")

# %%
ls
# Out:
# Dense/              histMobile-1.csv   histVgg19.csv       trMobile.ipynb
# Mobile/             histMobile-2.csv   histX-1.csv         trNas.ipynb
# Visualize.ipynb     histMobile-3.csv   histX-2.csv         trRes.ipynb
# X/                  histMobile-4.csv   histX.csv           trVgg.ipynb
# histDense121.csv    histMobile.csv     logs/               trX.ipynb
# histDense169-1.csv  histMobileV2.csv   pre-trained.ipynb   train/
# histDense169.csv    histNas.csv        test/               validation/
# histDense201.csv    histNasMobile.csv  trDense.ipynb
# histIncResV2.csv    histRes.csv        trIncepResV2.ipynb
# histIncV3.csv       histVgg.csv        trIncepV3.ipynb

# %%
M
