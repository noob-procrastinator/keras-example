# %%
from tensorflow.keras.applications.xception import Xception
import numpy as np
import pandas as pd
from matplotlib import ticker
#import seaborn as sn
import PIL
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
import subprocess as sp
import os


def mask_unused_gpus(leave_unmasked=1):
  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"

  try:
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    available_gpus = [i for i, x in enumerate(memory_free_values) if x > ACCEPTABLE_AVAILABLE_MEMORY]

    if len(available_gpus) < leave_unmasked: raise ValueError('Found only %d usable GPUs in the system' % len(available_gpus))
    os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, available_gpus[:leave_unmasked]))
  except Exception as e:
    print('"nvidia-smi" is probably not installed. GPUs are not masked', e)

mask_unused_gpus()


#os.environ["CUDA_VISIBLE_DEVICES"]="7"

# %%
traingen = image.ImageDataGenerator(rescale=1./255)#,rotation_range=10,width_shift_range=20,height_shift_range=10,shear_range=10,horizontal_flip=True,vertical_flip=True)
validationgen = image.ImageDataGenerator(rescale=1./255)
testgen = image.ImageDataGenerator(rescale=1./255)

train = traingen.flow_from_directory("train",target_size=(500, 825), batch_size=50, shuffle=True)
val = validationgen.flow_from_directory("validation",target_size=(500, 825), batch_size=56, shuffle=False)
test=testgen.flow_from_directory("test",target_size=(500, 825), batch_size=32, shuffle=False)
# Out:
# Found 2049 images belonging to 16 classes.
# Found 684 images belonging to 16 classes.
# Found 683 images belonging to 16 classes.

# %%
call_list = [tf.keras.callbacks.ModelCheckpoint(
                 filepath='./X/trX-{epoch:02d}-{val_categorical_accuracy:.4f}-{categorical_accuracy:.4f}.h5',
                 monitor='val_categorical_accuracy',
                 save_best_only=False,),
             
             tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta=0.001,patience=4,),
             tf.keras.callbacks.EarlyStopping(monitor='categorical_accuracy',min_delta=0.0005,patience=6,),
             tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy',min_delta=0.0005,patience=8,),
             
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_delta=0.005,),
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',factor=0.5,patience=4,min_delta=0.005,)
            ]

base = Xception(include_top=False,
                weights="imagenet",
                input_shape=(500, 825, 3))

x = base.output
x= layers.Flatten()(x)
#x = layers.Dropout(0.5)(x)
#x = layers.GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
#x = layers.Dense(16, activation='selu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
predictions = layers.Dense(16, activation='softmax')(x) #, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)

model = Model(inputs=base.input, outputs=predictions)

# this is the model we will train

for layer in base.layers:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=["categorical_accuracy","top_k_categorical_accuracy"])

history = model.fit_generator(train,
                             #callbacks=call_list,
                              steps_per_epoch=np.ceil(2049/50),
                              epochs=50,
                              verbose=2,
                              validation_data= val,
                              validation_steps=np.ceil(684/56)
                              )
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histXpre1.csv")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1108 13:06:40.015568 140711676913472 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/50
# 41/41 - 86s - loss: 18.3303 - categorical_accuracy: 0.4729 - top_k_categorical_accuracy: 0.7804 - val_loss: 21.7214 - val_categorical_accuracy: 0.3977 - val_top_k_categorical_accuracy: 0.7646
# Epoch 2/50
# 41/41 - 39s - loss: 1.9424 - categorical_accuracy: 0.9043 - top_k_categorical_accuracy: 0.9888 - val_loss: 24.8747 - val_categorical_accuracy: 0.3743 - val_top_k_categorical_accuracy: 0.7822
# Epoch 3/50
# 41/41 - 39s - loss: 0.4529 - categorical_accuracy: 0.9663 - top_k_categorical_accuracy: 0.9990 - val_loss: 36.7090 - val_categorical_accuracy: 0.2602 - val_top_k_categorical_accuracy: 0.8348
# Epoch 4/50
# 41/41 - 39s - loss: 0.3341 - categorical_accuracy: 0.9727 - top_k_categorical_accuracy: 0.9995 - val_loss: 28.2469 - val_categorical_accuracy: 0.3757 - val_top_k_categorical_accuracy: 0.7822
# Epoch 5/50
# 41/41 - 39s - loss: 0.4532 - categorical_accuracy: 0.9732 - top_k_categorical_accuracy: 0.9995 - val_loss: 28.3395 - val_categorical_accuracy: 0.3655 - val_top_k_categorical_accuracy: 0.7339
# Epoch 6/50
# 41/41 - 39s - loss: 0.3934 - categorical_accuracy: 0.9722 - top_k_categorical_accuracy: 1.0000 - val_loss: 39.8298 - val_categorical_accuracy: 0.3041 - val_top_k_categorical_accuracy: 0.7544
# Epoch 7/50
# 41/41 - 39s - loss: 0.4512 - categorical_accuracy: 0.9736 - top_k_categorical_accuracy: 1.0000 - val_loss: 48.2641 - val_categorical_accuracy: 0.2792 - val_top_k_categorical_accuracy: 0.8202
# Epoch 8/50
# 41/41 - 39s - loss: 0.4183 - categorical_accuracy: 0.9751 - top_k_categorical_accuracy: 0.9990 - val_loss: 32.6334 - val_categorical_accuracy: 0.3684 - val_top_k_categorical_accuracy: 0.8421
# Epoch 9/50
# 41/41 - 39s - loss: 0.2671 - categorical_accuracy: 0.9839 - top_k_categorical_accuracy: 0.9995 - val_loss: 49.2473 - val_categorical_accuracy: 0.2953 - val_top_k_categorical_accuracy: 0.8509
# Epoch 10/50
# 41/41 - 39s - loss: 0.2057 - categorical_accuracy: 0.9839 - top_k_categorical_accuracy: 1.0000 - val_loss: 31.2790 - val_categorical_accuracy: 0.4035 - val_top_k_categorical_accuracy: 0.8567
# Epoch 11/50
# 41/41 - 39s - loss: 0.2349 - categorical_accuracy: 0.9868 - top_k_categorical_accuracy: 1.0000 - val_loss: 41.1726 - val_categorical_accuracy: 0.3538 - val_top_k_categorical_accuracy: 0.8406
# Epoch 12/50
# 41/41 - 39s - loss: 0.0852 - categorical_accuracy: 0.9912 - top_k_categorical_accuracy: 0.9995 - val_loss: 36.6233 - val_categorical_accuracy: 0.3947 - val_top_k_categorical_accuracy: 0.8319
# Epoch 13/50
# 41/41 - 39s - loss: 0.4409 - categorical_accuracy: 0.9800 - top_k_categorical_accuracy: 0.9995 - val_loss: 30.9238 - val_categorical_accuracy: 0.4284 - val_top_k_categorical_accuracy: 0.8523
# Epoch 14/50
# 41/41 - 39s - loss: 0.5828 - categorical_accuracy: 0.9693 - top_k_categorical_accuracy: 0.9995 - val_loss: 38.6213 - val_categorical_accuracy: 0.3874 - val_top_k_categorical_accuracy: 0.8684
# Epoch 15/50
# 41/41 - 39s - loss: 1.0227 - categorical_accuracy: 0.9614 - top_k_categorical_accuracy: 0.9980 - val_loss: 42.3390 - val_categorical_accuracy: 0.3845 - val_top_k_categorical_accuracy: 0.8523
# Epoch 16/50
# 41/41 - 39s - loss: 0.7838 - categorical_accuracy: 0.9712 - top_k_categorical_accuracy: 0.9985 - val_loss: 41.6182 - val_categorical_accuracy: 0.4269 - val_top_k_categorical_accuracy: 0.8509
# Epoch 17/50
# 41/41 - 39s - loss: 0.6514 - categorical_accuracy: 0.9766 - top_k_categorical_accuracy: 0.9985 - val_loss: 45.7295 - val_categorical_accuracy: 0.4313 - val_top_k_categorical_accuracy: 0.8553
# Epoch 18/50
# 41/41 - 39s - loss: 0.4118 - categorical_accuracy: 0.9834 - top_k_categorical_accuracy: 1.0000 - val_loss: 44.2224 - val_categorical_accuracy: 0.4123 - val_top_k_categorical_accuracy: 0.8743
# Epoch 19/50
# 41/41 - 39s - loss: 0.2433 - categorical_accuracy: 0.9863 - top_k_categorical_accuracy: 1.0000 - val_loss: 47.6637 - val_categorical_accuracy: 0.3977 - val_top_k_categorical_accuracy: 0.8699
# Epoch 20/50
# 41/41 - 40s - loss: 0.2636 - categorical_accuracy: 0.9883 - top_k_categorical_accuracy: 1.0000 - val_loss: 45.7187 - val_categorical_accuracy: 0.3991 - val_top_k_categorical_accuracy: 0.8918
# Epoch 21/50
# 41/41 - 39s - loss: 0.2399 - categorical_accuracy: 0.9868 - top_k_categorical_accuracy: 1.0000 - val_loss: 55.4007 - val_categorical_accuracy: 0.3538 - val_top_k_categorical_accuracy: 0.9313
# Epoch 22/50
# 41/41 - 39s - loss: 0.1565 - categorical_accuracy: 0.9927 - top_k_categorical_accuracy: 1.0000 - val_loss: 44.0182 - val_categorical_accuracy: 0.4313 - val_top_k_categorical_accuracy: 0.9108
# Epoch 23/50
# 41/41 - 39s - loss: 0.4721 - categorical_accuracy: 0.9839 - top_k_categorical_accuracy: 1.0000 - val_loss: 46.7753 - val_categorical_accuracy: 0.4386 - val_top_k_categorical_accuracy: 0.8538
# Epoch 24/50
# 41/41 - 39s - loss: 0.3906 - categorical_accuracy: 0.9824 - top_k_categorical_accuracy: 1.0000 - val_loss: 36.8988 - val_categorical_accuracy: 0.5117 - val_top_k_categorical_accuracy: 0.9254
# Epoch 25/50
# 41/41 - 39s - loss: 0.6243 - categorical_accuracy: 0.9800 - top_k_categorical_accuracy: 0.9990 - val_loss: 42.9134 - val_categorical_accuracy: 0.4488 - val_top_k_categorical_accuracy: 0.9254
# Epoch 26/50
# 41/41 - 39s - loss: 0.4307 - categorical_accuracy: 0.9863 - top_k_categorical_accuracy: 0.9995 - val_loss: 46.5820 - val_categorical_accuracy: 0.4152 - val_top_k_categorical_accuracy: 0.9240
# Epoch 27/50
# 41/41 - 39s - loss: 0.4963 - categorical_accuracy: 0.9873 - top_k_categorical_accuracy: 1.0000 - val_loss: 44.2105 - val_categorical_accuracy: 0.4430 - val_top_k_categorical_accuracy: 0.9152
# Epoch 28/50
# 41/41 - 39s - loss: 0.8964 - categorical_accuracy: 0.9780 - top_k_categorical_accuracy: 1.0000 - val_loss: 55.2978 - val_categorical_accuracy: 0.3947 - val_top_k_categorical_accuracy: 0.9620
# Epoch 29/50
# 41/41 - 39s - loss: 0.5244 - categorical_accuracy: 0.9839 - top_k_categorical_accuracy: 0.9995 - val_loss: 48.9394 - val_categorical_accuracy: 0.4094 - val_top_k_categorical_accuracy: 0.9649
# Epoch 30/50
# 41/41 - 39s - loss: 0.3609 - categorical_accuracy: 0.9888 - top_k_categorical_accuracy: 1.0000 - val_loss: 46.9155 - val_categorical_accuracy: 0.4298 - val_top_k_categorical_accuracy: 0.9357
# Epoch 31/50
# 41/41 - 39s - loss: 0.1127 - categorical_accuracy: 0.9941 - top_k_categorical_accuracy: 1.0000 - val_loss: 53.4132 - val_categorical_accuracy: 0.4240 - val_top_k_categorical_accuracy: 0.9240
# Epoch 32/50
# 41/41 - 39s - loss: 0.2993 - categorical_accuracy: 0.9912 - top_k_categorical_accuracy: 1.0000 - val_loss: 44.8283 - val_categorical_accuracy: 0.4649 - val_top_k_categorical_accuracy: 0.9342
# Epoch 33/50
# 41/41 - 39s - loss: 0.1793 - categorical_accuracy: 0.9956 - top_k_categorical_accuracy: 1.0000 - val_loss: 53.0902 - val_categorical_accuracy: 0.4123 - val_top_k_categorical_accuracy: 0.9444
# Epoch 34/50
# 41/41 - 39s - loss: 0.2140 - categorical_accuracy: 0.9937 - top_k_categorical_accuracy: 1.0000 - val_loss: 43.9257 - val_categorical_accuracy: 0.4737 - val_top_k_categorical_accuracy: 0.9386
# Epoch 35/50
# 41/41 - 40s - loss: 0.0762 - categorical_accuracy: 0.9946 - top_k_categorical_accuracy: 1.0000 - val_loss: 45.2959 - val_categorical_accuracy: 0.4664 - val_top_k_categorical_accuracy: 0.9196
# Epoch 36/50
# 41/41 - 39s - loss: 0.2016 - categorical_accuracy: 0.9922 - top_k_categorical_accuracy: 0.9995 - val_loss: 41.4400 - val_categorical_accuracy: 0.4985 - val_top_k_categorical_accuracy: 0.9181
# Epoch 37/50
# 41/41 - 39s - loss: 0.2814 - categorical_accuracy: 0.9917 - top_k_categorical_accuracy: 1.0000 - val_loss: 71.0438 - val_categorical_accuracy: 0.3275 - val_top_k_categorical_accuracy: 0.9635
# Epoch 38/50
# 41/41 - 39s - loss: 0.0901 - categorical_accuracy: 0.9951 - top_k_categorical_accuracy: 1.0000 - val_loss: 51.2981 - val_categorical_accuracy: 0.4430 - val_top_k_categorical_accuracy: 0.9532
# Epoch 39/50
# 41/41 - 39s - loss: 0.3086 - categorical_accuracy: 0.9922 - top_k_categorical_accuracy: 1.0000 - val_loss: 43.8040 - val_categorical_accuracy: 0.4795 - val_top_k_categorical_accuracy: 0.9240
# Epoch 40/50
# 41/41 - 39s - loss: 0.1497 - categorical_accuracy: 0.9961 - top_k_categorical_accuracy: 1.0000 - val_loss: 43.7772 - val_categorical_accuracy: 0.4825 - val_top_k_categorical_accuracy: 0.9094
# Epoch 41/50
# 41/41 - 39s - loss: 0.2992 - categorical_accuracy: 0.9946 - top_k_categorical_accuracy: 0.9995 - val_loss: 41.3892 - val_categorical_accuracy: 0.5044 - val_top_k_categorical_accuracy: 0.9225
# Epoch 42/50
# 41/41 - 39s - loss: 0.1879 - categorical_accuracy: 0.9941 - top_k_categorical_accuracy: 1.0000 - val_loss: 51.0213 - val_categorical_accuracy: 0.4839 - val_top_k_categorical_accuracy: 0.9269
# Epoch 43/50
# 41/41 - 39s - loss: 0.1163 - categorical_accuracy: 0.9932 - top_k_categorical_accuracy: 1.0000 - val_loss: 54.5501 - val_categorical_accuracy: 0.4167 - val_top_k_categorical_accuracy: 0.9342
# Epoch 44/50
# 41/41 - 39s - loss: 0.1475 - categorical_accuracy: 0.9946 - top_k_categorical_accuracy: 1.0000 - val_loss: 65.9165 - val_categorical_accuracy: 0.3991 - val_top_k_categorical_accuracy: 0.9518
# Epoch 45/50
# 41/41 - 39s - loss: 0.2593 - categorical_accuracy: 0.9902 - top_k_categorical_accuracy: 1.0000 - val_loss: 56.3489 - val_categorical_accuracy: 0.4591 - val_top_k_categorical_accuracy: 0.9371
# Epoch 46/50
# 41/41 - 39s - loss: 0.1338 - categorical_accuracy: 0.9922 - top_k_categorical_accuracy: 0.9995 - val_loss: 72.4401 - val_categorical_accuracy: 0.3962 - val_top_k_categorical_accuracy: 0.9444
# Epoch 47/50
# 41/41 - 40s - loss: 0.3469 - categorical_accuracy: 0.9902 - top_k_categorical_accuracy: 1.0000 - val_loss: 71.0891 - val_categorical_accuracy: 0.3962 - val_top_k_categorical_accuracy: 0.9298
# Epoch 48/50
# 41/41 - 39s - loss: 0.4343 - categorical_accuracy: 0.9858 - top_k_categorical_accuracy: 1.0000 - val_loss: 62.1140 - val_categorical_accuracy: 0.4167 - val_top_k_categorical_accuracy: 0.9488
# Epoch 49/50
# 41/41 - 39s - loss: 0.3454 - categorical_accuracy: 0.9898 - top_k_categorical_accuracy: 0.9995 - val_loss: 72.6425 - val_categorical_accuracy: 0.4050 - val_top_k_categorical_accuracy: 0.9708
# Epoch 50/50
# 41/41 - 39s - loss: 0.3018 - categorical_accuracy: 0.9927 - top_k_categorical_accuracy: 1.0000 - val_loss: 53.9133 - val_categorical_accuracy: 0.4839 - val_top_k_categorical_accuracy: 0.9503

# %%
def smooth(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['loss']),color="Blue")
plt.plot(history.history['loss'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_loss']),color="Red")
plt.plot(history.history['val_loss'],alpha=0.2,color="Red")
plt.ylabel('loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train', 'train real','validation', 'validation real'], loc='upper right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['categorical_accuracy']),color="Blue")
plt.plot(history.history['categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_categorical_accuracy']),color="Red")
plt.plot(history.history['val_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['top_k_categorical_accuracy']),color="Blue")
plt.plot(history.history['top_k_categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_top_k_categorical_accuracy']),color="Red")
plt.plot(history.history['val_top_k_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()

# %%
import pandas as pd
    
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histX.csv")
