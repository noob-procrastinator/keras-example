# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3 as b
import numpy as np
import pandas as pd
from matplotlib import ticker
#import seaborn as sn
import PIL
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
import subprocess as sp
import os

def mask_unused_gpus(leave_unmasked=1):
  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"

  try:
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    available_gpus = [i for i, x in enumerate(memory_free_values) if x > ACCEPTABLE_AVAILABLE_MEMORY]

    if len(available_gpus) < leave_unmasked: raise ValueError('Found only %d usable GPUs in the system' % len(available_gpus))
    os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, available_gpus[:leave_unmasked]))
  except Exception as e:
    print('"nvidia-smi" is probably not installed. GPUs are not masked', e)

mask_unused_gpus()

# %%
traingen = image.ImageDataGenerator(rescale=1./255)#,rotation_range=10,width_shift_range=20,height_shift_range=10,shear_range=10,horizontal_flip=True,vertical_flip=True)
validationgen = image.ImageDataGenerator(rescale=1./255)
testgen = image.ImageDataGenerator(rescale=1./255)

train = traingen.flow_from_directory("train",target_size=(500, 825), batch_size=50, shuffle=True)
val = validationgen.flow_from_directory("validation",target_size=(500, 825), batch_size=56, shuffle=False)
test=testgen.flow_from_directory("test",target_size=(500, 825), batch_size=32, shuffle=False)
# Out:
# Found 2049 images belonging to 16 classes.
# Found 684 images belonging to 16 classes.
# Found 683 images belonging to 16 classes.

# %%
call_list = [tf.keras.callbacks.ModelCheckpoint(
                 filepath='./InV3/trIncV3-{epoch:02d}-{val_categorical_accuracy:.4f}-{categorical_accuracy:.4f}.h5',
                 monitor='val_categorical_accuracy',
                 save_best_only=False,),
             
             tf.keras.callbacks.EarlyStopping(monitor='loss',min_delta=0.001,patience=4,),
             tf.keras.callbacks.EarlyStopping(monitor='categorical_accuracy',min_delta=0.0005,patience=6,),
             tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy',min_delta=0.0005,patience=8,),
             
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_delta=0.005,),
             tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',factor=0.5,patience=4,min_delta=0.005,)
            ]


base = b(include_top=False,
                weights="imagenet",
                input_shape=(500, 825, 3),
               pooling="max")

x = base.output
#x = layers.Dropout(0.5)(x)
#x = layers.GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
#x = layers.Dense(16, activation='selu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
predictions = layers.Dense(16, activation='softmax')(x)#, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)

model = Model(inputs=base.input, outputs=predictions)

# this is the model we will train

for layer in base.layers:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=["categorical_accuracy","top_k_categorical_accuracy"])

history = model.fit_generator(train,
                              #callbacks=call_list,
                              steps_per_epoch=np.ceil(2049/50),
                              epochs=50,
                              verbose=2,
                              validation_data= val,
                              validation_steps=np.ceil(684/56)
                              )

hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("histIncV3pre.csv")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1103 15:36:50.125630 140085201155904 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 21s 0us/step
# Epoch 1/50
# 41/41 - 47s - loss: 6.1291 - categorical_accuracy: 0.0869 - top_k_categorical_accuracy: 0.3807 - val_loss: 3.6651 - val_categorical_accuracy: 0.1170 - val_top_k_categorical_accuracy: 0.3830
# Epoch 2/50
# 41/41 - 38s - loss: 3.3908 - categorical_accuracy: 0.2016 - top_k_categorical_accuracy: 0.5886 - val_loss: 3.1110 - val_categorical_accuracy: 0.1681 - val_top_k_categorical_accuracy: 0.5278
# Epoch 3/50
# 41/41 - 38s - loss: 2.7007 - categorical_accuracy: 0.3216 - top_k_categorical_accuracy: 0.7199 - val_loss: 3.1939 - val_categorical_accuracy: 0.1813 - val_top_k_categorical_accuracy: 0.5307
# Epoch 4/50
# 41/41 - 38s - loss: 2.2276 - categorical_accuracy: 0.4070 - top_k_categorical_accuracy: 0.8009 - val_loss: 2.8199 - val_categorical_accuracy: 0.1959 - val_top_k_categorical_accuracy: 0.6404
# Epoch 5/50
# 41/41 - 38s - loss: 1.9479 - categorical_accuracy: 0.4680 - top_k_categorical_accuracy: 0.8404 - val_loss: 2.6939 - val_categorical_accuracy: 0.2924 - val_top_k_categorical_accuracy: 0.6491
# Epoch 6/50
# 41/41 - 38s - loss: 1.9506 - categorical_accuracy: 0.4924 - top_k_categorical_accuracy: 0.8487 - val_loss: 2.8286 - val_categorical_accuracy: 0.2705 - val_top_k_categorical_accuracy: 0.6594
# Epoch 7/50
# 41/41 - 37s - loss: 1.5235 - categorical_accuracy: 0.5681 - top_k_categorical_accuracy: 0.8946 - val_loss: 2.7862 - val_categorical_accuracy: 0.3099 - val_top_k_categorical_accuracy: 0.6535
# Epoch 8/50
# 41/41 - 38s - loss: 1.3651 - categorical_accuracy: 0.6032 - top_k_categorical_accuracy: 0.9092 - val_loss: 2.7327 - val_categorical_accuracy: 0.2997 - val_top_k_categorical_accuracy: 0.6520
# Epoch 9/50
# 41/41 - 37s - loss: 1.3107 - categorical_accuracy: 0.6262 - top_k_categorical_accuracy: 0.9141 - val_loss: 2.3970 - val_categorical_accuracy: 0.3611 - val_top_k_categorical_accuracy: 0.7193
# Epoch 10/50
# 41/41 - 38s - loss: 1.1642 - categorical_accuracy: 0.6540 - top_k_categorical_accuracy: 0.9336 - val_loss: 2.6280 - val_categorical_accuracy: 0.3348 - val_top_k_categorical_accuracy: 0.6696
# Epoch 11/50
# 41/41 - 37s - loss: 1.0763 - categorical_accuracy: 0.6857 - top_k_categorical_accuracy: 0.9449 - val_loss: 2.5159 - val_categorical_accuracy: 0.3480 - val_top_k_categorical_accuracy: 0.6842
# Epoch 12/50
# 41/41 - 38s - loss: 1.0234 - categorical_accuracy: 0.7018 - top_k_categorical_accuracy: 0.9439 - val_loss: 2.4021 - val_categorical_accuracy: 0.3494 - val_top_k_categorical_accuracy: 0.7237
# Epoch 13/50
# 41/41 - 37s - loss: 0.9850 - categorical_accuracy: 0.7023 - top_k_categorical_accuracy: 0.9478 - val_loss: 2.3003 - val_categorical_accuracy: 0.3728 - val_top_k_categorical_accuracy: 0.7427
# Epoch 14/50
# 41/41 - 38s - loss: 0.8367 - categorical_accuracy: 0.7404 - top_k_categorical_accuracy: 0.9697 - val_loss: 2.5351 - val_categorical_accuracy: 0.3392 - val_top_k_categorical_accuracy: 0.7018
# Epoch 15/50
# 41/41 - 38s - loss: 0.8407 - categorical_accuracy: 0.7306 - top_k_categorical_accuracy: 0.9653 - val_loss: 2.7805 - val_categorical_accuracy: 0.3392 - val_top_k_categorical_accuracy: 0.6959
# Epoch 16/50
# 41/41 - 38s - loss: 0.8165 - categorical_accuracy: 0.7326 - top_k_categorical_accuracy: 0.9707 - val_loss: 2.6653 - val_categorical_accuracy: 0.3319 - val_top_k_categorical_accuracy: 0.7164
# Epoch 17/50
# 41/41 - 38s - loss: 0.6603 - categorical_accuracy: 0.7911 - top_k_categorical_accuracy: 0.9790 - val_loss: 2.9480 - val_categorical_accuracy: 0.3114 - val_top_k_categorical_accuracy: 0.6681
# Epoch 18/50
# 41/41 - 37s - loss: 0.6436 - categorical_accuracy: 0.7921 - top_k_categorical_accuracy: 0.9766 - val_loss: 2.6670 - val_categorical_accuracy: 0.3582 - val_top_k_categorical_accuracy: 0.7003
# Epoch 19/50
# 41/41 - 38s - loss: 0.6228 - categorical_accuracy: 0.8058 - top_k_categorical_accuracy: 0.9800 - val_loss: 2.6032 - val_categorical_accuracy: 0.3567 - val_top_k_categorical_accuracy: 0.7018
# Epoch 20/50
# 41/41 - 38s - loss: 0.6334 - categorical_accuracy: 0.7975 - top_k_categorical_accuracy: 0.9824 - val_loss: 2.4618 - val_categorical_accuracy: 0.3772 - val_top_k_categorical_accuracy: 0.7383
# Epoch 21/50
# 41/41 - 40s - loss: 0.5557 - categorical_accuracy: 0.8180 - top_k_categorical_accuracy: 0.9805 - val_loss: 2.7900 - val_categorical_accuracy: 0.3465 - val_top_k_categorical_accuracy: 0.6915
# Epoch 22/50
# 41/41 - 41s - loss: 0.6691 - categorical_accuracy: 0.7887 - top_k_categorical_accuracy: 0.9824 - val_loss: 2.9675 - val_categorical_accuracy: 0.3450 - val_top_k_categorical_accuracy: 0.6827
# Epoch 23/50
# 41/41 - 41s - loss: 0.5449 - categorical_accuracy: 0.8253 - top_k_categorical_accuracy: 0.9839 - val_loss: 2.4062 - val_categorical_accuracy: 0.3655 - val_top_k_categorical_accuracy: 0.7427
# Epoch 24/50
# 41/41 - 42s - loss: 0.4993 - categorical_accuracy: 0.8316 - top_k_categorical_accuracy: 0.9917 - val_loss: 2.7871 - val_categorical_accuracy: 0.3289 - val_top_k_categorical_accuracy: 0.7193
# Epoch 25/50
# 41/41 - 43s - loss: 0.5766 - categorical_accuracy: 0.8180 - top_k_categorical_accuracy: 0.9805 - val_loss: 2.8421 - val_categorical_accuracy: 0.3421 - val_top_k_categorical_accuracy: 0.6974
# Epoch 26/50
# 41/41 - 44s - loss: 0.4984 - categorical_accuracy: 0.8409 - top_k_categorical_accuracy: 0.9873 - val_loss: 2.7229 - val_categorical_accuracy: 0.3377 - val_top_k_categorical_accuracy: 0.7383
# Epoch 27/50
# 41/41 - 44s - loss: 0.4951 - categorical_accuracy: 0.8389 - top_k_categorical_accuracy: 0.9819 - val_loss: 2.6434 - val_categorical_accuracy: 0.3450 - val_top_k_categorical_accuracy: 0.7471
# Epoch 28/50
# 41/41 - 44s - loss: 0.4854 - categorical_accuracy: 0.8424 - top_k_categorical_accuracy: 0.9917 - val_loss: 2.6550 - val_categorical_accuracy: 0.3757 - val_top_k_categorical_accuracy: 0.7222
# Epoch 29/50
# 41/41 - 43s - loss: 0.5186 - categorical_accuracy: 0.8399 - top_k_categorical_accuracy: 0.9849 - val_loss: 2.5414 - val_categorical_accuracy: 0.4020 - val_top_k_categorical_accuracy: 0.7383
# Epoch 30/50
# 41/41 - 43s - loss: 0.4050 - categorical_accuracy: 0.8677 - top_k_categorical_accuracy: 0.9937 - val_loss: 2.5064 - val_categorical_accuracy: 0.4020 - val_top_k_categorical_accuracy: 0.7427
# Epoch 31/50
# 41/41 - 44s - loss: 0.3429 - categorical_accuracy: 0.8882 - top_k_categorical_accuracy: 0.9941 - val_loss: 2.4330 - val_categorical_accuracy: 0.3918 - val_top_k_categorical_accuracy: 0.7734
# Epoch 32/50
# 41/41 - 45s - loss: 0.3352 - categorical_accuracy: 0.8970 - top_k_categorical_accuracy: 0.9932 - val_loss: 2.6049 - val_categorical_accuracy: 0.3845 - val_top_k_categorical_accuracy: 0.7339
# Epoch 33/50
# 41/41 - 44s - loss: 0.3614 - categorical_accuracy: 0.8799 - top_k_categorical_accuracy: 0.9966 - val_loss: 2.7810 - val_categorical_accuracy: 0.3713 - val_top_k_categorical_accuracy: 0.7149
# Epoch 34/50
# 41/41 - 44s - loss: 0.3766 - categorical_accuracy: 0.8751 - top_k_categorical_accuracy: 0.9927 - val_loss: 2.6923 - val_categorical_accuracy: 0.3538 - val_top_k_categorical_accuracy: 0.7237
# Epoch 35/50
# 41/41 - 45s - loss: 0.2897 - categorical_accuracy: 0.9004 - top_k_categorical_accuracy: 0.9961 - val_loss: 2.8326 - val_categorical_accuracy: 0.3582 - val_top_k_categorical_accuracy: 0.7018
# Epoch 36/50
# 41/41 - 44s - loss: 0.2586 - categorical_accuracy: 0.9122 - top_k_categorical_accuracy: 0.9971 - val_loss: 2.8091 - val_categorical_accuracy: 0.3553 - val_top_k_categorical_accuracy: 0.7251
# Epoch 37/50
# 41/41 - 44s - loss: 0.3074 - categorical_accuracy: 0.8985 - top_k_categorical_accuracy: 0.9976 - val_loss: 2.7408 - val_categorical_accuracy: 0.3713 - val_top_k_categorical_accuracy: 0.7442
# Epoch 38/50
# 41/41 - 44s - loss: 0.2537 - categorical_accuracy: 0.9180 - top_k_categorical_accuracy: 0.9971 - val_loss: 2.7938 - val_categorical_accuracy: 0.3509 - val_top_k_categorical_accuracy: 0.7281
# Epoch 39/50
# 41/41 - 43s - loss: 0.2346 - categorical_accuracy: 0.9190 - top_k_categorical_accuracy: 0.9990 - val_loss: 2.4833 - val_categorical_accuracy: 0.3933 - val_top_k_categorical_accuracy: 0.7398
# Epoch 40/50
# 41/41 - 44s - loss: 0.2790 - categorical_accuracy: 0.9078 - top_k_categorical_accuracy: 0.9976 - val_loss: 2.5204 - val_categorical_accuracy: 0.4020 - val_top_k_categorical_accuracy: 0.7632
# Epoch 41/50
# 41/41 - 43s - loss: 0.2997 - categorical_accuracy: 0.9029 - top_k_categorical_accuracy: 0.9971 - val_loss: 2.6043 - val_categorical_accuracy: 0.3816 - val_top_k_categorical_accuracy: 0.7427
# Epoch 42/50
# 41/41 - 43s - loss: 0.1877 - categorical_accuracy: 0.9375 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.7903 - val_categorical_accuracy: 0.3494 - val_top_k_categorical_accuracy: 0.7471
# Epoch 43/50
# 41/41 - 43s - loss: 0.3038 - categorical_accuracy: 0.8980 - top_k_categorical_accuracy: 0.9971 - val_loss: 2.8423 - val_categorical_accuracy: 0.3728 - val_top_k_categorical_accuracy: 0.7442
# Epoch 44/50
# 41/41 - 42s - loss: 0.2396 - categorical_accuracy: 0.9190 - top_k_categorical_accuracy: 0.9980 - val_loss: 2.5209 - val_categorical_accuracy: 0.3860 - val_top_k_categorical_accuracy: 0.7558
# Epoch 45/50
# 41/41 - 44s - loss: 0.2255 - categorical_accuracy: 0.9253 - top_k_categorical_accuracy: 0.9985 - val_loss: 2.5413 - val_categorical_accuracy: 0.4254 - val_top_k_categorical_accuracy: 0.7558
# Epoch 46/50
# 41/41 - 44s - loss: 0.2383 - categorical_accuracy: 0.9200 - top_k_categorical_accuracy: 0.9990 - val_loss: 2.8139 - val_categorical_accuracy: 0.3655 - val_top_k_categorical_accuracy: 0.7281
# Epoch 47/50
# 41/41 - 43s - loss: 0.2980 - categorical_accuracy: 0.9000 - top_k_categorical_accuracy: 0.9951 - val_loss: 2.9217 - val_categorical_accuracy: 0.3918 - val_top_k_categorical_accuracy: 0.7061
# Epoch 48/50
# 41/41 - 43s - loss: 0.1712 - categorical_accuracy: 0.9385 - top_k_categorical_accuracy: 0.9995 - val_loss: 3.0820 - val_categorical_accuracy: 0.3450 - val_top_k_categorical_accuracy: 0.7281
# Epoch 49/50
# 41/41 - 43s - loss: 0.2112 - categorical_accuracy: 0.9283 - top_k_categorical_accuracy: 0.9966 - val_loss: 2.6784 - val_categorical_accuracy: 0.3860 - val_top_k_categorical_accuracy: 0.7632
# Epoch 50/50
# 41/41 - 43s - loss: 0.1532 - categorical_accuracy: 0.9546 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.9707 - val_categorical_accuracy: 0.3450 - val_top_k_categorical_accuracy: 0.7178

# %%
def smooth(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=18)
plt.plot(smooth(history.history['loss']),color="Blue")
plt.plot(history.history['loss'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_loss']),color="Red")
plt.plot(history.history['val_loss'],alpha=0.2,color="Red")
plt.ylabel('loss',fontsize=20)
plt.ylim(0,6)
plt.xlabel('epoch',fontsize=20)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train', 'train real','validation', 'validation real'], loc='upper right',fontsize=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,7))
ax.tick_params(labelsize=14)
plt.plot(smooth(history.history['categorical_accuracy']),color="Blue")
plt.plot(history.history['categorical_accuracy'],alpha=0.2,color="Blue")
plt.plot(smooth(history.history['val_categorical_accuracy']),color="Red")
plt.plot(history.history['val_categorical_accuracy'],alpha=0.2,color="Red")
plt.ylabel('acc',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.grid(b=True, which='major', color='#444444', linestyle='-',alpha=0.7)
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#plt.yscale("log")
plt.legend(['train','train real', 'validation', 'validation real'], loc='lower right',fontsize=15)
plt.show()
